# %%
import numpy as np
import scipy
from sklearn.cluster import KMeans
from sklearn.manifold import TSNE
from sklearn.covariance import shrunk_covariance
import seaborn as sns
import matplotlib.pyplot as plt
from pylab import mpl

import dill
import os

import torch
from utils.generate_and_plot_signals import generate_signals, plot_signals, plot_source_signals
from utils import AutoEncoder_Network, draw_states, ttest_for_clusters
from utils.calc_fun import calc_diff

os.environ["OMP_NUM_THREADS"] = "4"

# %%
plt.rcParams['font.family']=['Arial', 'Times New Roman']
plt.style.use('default')
mpl.rcParams["axes.unicode_minus"] = False
# %config InlineBackend.figure_format = 'svg'

font = {'family':['Arial', 'Times New Roman'], 'color':'k', 'weight':'normal', 'size':10 }
colors = sns.color_palette('tab10')

# %% [markdown]
# # Generate or load data

# %%
# generate 50 random trials

n_trials = 50
n_ch = 6
n_times = 1001

raw_data = np.empty((n_trials, n_ch, n_times))
Atrue = np.random.random([n_ch, n_ch])

for t in range(n_trials):
    Strue = generate_signals(stationary=False)
    raw_data[t] = Atrue.dot(Strue)

X = raw_data[0]

# with open('./saves/generate_data.pkl', 'wb') as f:
#     dill.dump([Strue, Atrue, raw_data], f)

# %%
with open('./saves/generate_data.pkl', 'rb') as f:
    [Strue, Atrue, raw_data] = dill.load(f)

# %%
plot_signals(Strue, figsize=(2.5, 1.5));
plot_source_signals(raw_data[0], figsize=(2.5, 1.5));

# %% [markdown]
# # Calculate spatial covariance matrix

# %%
times = raw_data.shape[2]
chs = raw_data.shape[1]
lag_num = 200
half_lag = int(lag_num*0.5)
len_t = times-lag_num

avg_data = np.mean(raw_data, axis=0)
crop_eeg = np.zeros((chs, len_t))

Cov_mat = np.empty((len_t, chs, chs))
Cov_uptri = np.empty(( len_t, int(chs*((chs+1)/2)) ))

index = 0
for t in range(half_lag, len_t+half_lag):
    crop_eeg[:, index] = avg_data[:, t]

    # calculate covariance
    cov = np.cov(avg_data[:, t-half_lag:t+half_lag]) 
    cov = shrunk_covariance(cov, shrinkage=0.01)
    Cov_mat[index] = cov
    Cov_uptri[index] = cov[np.triu_indices(cov.shape[0], k=0)]
    index += 1

Cov_uptri.shape
# Out:
# (801, 21)

# %%
# Normalize the upper triangular elements of the matrix
Cov_uptri_norm = Cov_uptri - np.mean(Cov_uptri)
Cov_uptri_norm /= np.std(Cov_uptri)

# %% [markdown]
# # T-SNE visualization

# %%
tsne = TSNE(n_components=2, init='pca', random_state=0, n_jobs=-1, perplexity=30)

tsne_2d = tsne.fit_transform(Cov_uptri)    

fig, axi1=plt.subplots(1, figsize=(2, 1.5))    
axi1.scatter(tsne_2d[:, 0], tsne_2d[:, 1],
            marker='*', s=10, color=sns.color_palette('Paired')[1],
            )

ax = plt.gca()
plt.xlim([-50, 50])
plt.ylim([-50, 50])
plt.grid(True, linewidth=0.5, color='gray', linestyle=':')

plt.yticks([-50,-25,0,25,50],[-50,-25,0,25,50])
plt.xticks([-50,-25,0,25,50],[-50,-25,0,25,50])

ax.tick_params(which='both', bottom=True, top=False, left=True, right=False,
            labelbottom=True, labelleft=True, direction='out',width=1)
plt.show()

# %% [markdown]
# # Train AutoEncoder Network

# %%
#[samples, features]
cov_data = torch.from_numpy(Cov_uptri_norm).type(torch.FloatTensor) 

device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')
print(device)
# Out:
# cuda:0

# %%
EPOCHS_PRE = 1001
LR_PRE = 1e-3 # dynamic adjust learning rate
BATCH_SIZE = 32

autoencoder = AutoEncoder_Network.AutoEncoder().to(device)
checkpoint = { "epoch": 0, "best": float("inf") }
file_path_prefix = './auto_encoder_saves/'
ae_save_path = file_path_prefix + 'autoencoder.pth'

# if os.path.isfile(ae_save_path):
#     print('Loading {}'.format(ae_save_path))
#     checkpoint = torch.load(ae_save_path)
#     autoencoder.load_state_dict(checkpoint['state_dict'])
# else:
#     print("=> no checkpoint found at '{}'".format(ae_save_path))
#     checkpoint = {
#         "epoch": 0,
#         "best": float("inf")
#     }

AutoEncoder_Network.train(train_data=cov_data, model=autoencoder, savepath=ae_save_path, checkpoint=checkpoint, 
                      num_epochs=EPOCHS_PRE, file_path_prefix=file_path_prefix, batch_size=BATCH_SIZE, lr=LR_PRE)
# Out:
# epoch [1/1001], MSE_loss:0.33897
# => Saving new checkpoint
# epoch [2/1001], MSE_loss:0.25612
# => Saving new checkpoint
# epoch [3/1001], MSE_loss:0.39415
# => Validation Accuracy did not improve
# epoch [4/1001], MSE_loss:0.58658
# => Validation Accuracy did not improve
# epoch [5/1001], MSE_loss:0.18890
# => Saving new checkpoint
# epoch [6/1001], MSE_loss:1.48388
# => Validation Accuracy did not improve
# epoch [7/1001], MSE_loss:0.40214
# => Validation Accuracy did not improve
# epoch [8/1001], MSE_loss:0.08100
# => Saving new checkpoint
# epoch [9/1001], MSE_loss:0.61565
# => Validation Accuracy did not improve
# epoch [10/1001], MSE_loss:0.59822
# => Validation Accuracy did not improve
# epoch [11/1001], MSE_loss:0.12581
# => Validation Accuracy did not improve
# epoch [12/1001], MSE_loss:0.04752
# => Saving new checkpoint
# epoch [13/1001], MSE_loss:0.16174
# => Validation Accuracy did not improve
# epoch [14/1001], MSE_loss:0.26776
# => Validation Accuracy did not improve
# epoch [15/1001], MSE_loss:0.02976
# => Saving new checkpoint
# epoch [16/1001], MSE_loss:0.16562
# => Validation Accuracy did not improve
# epoch [17/1001], MSE_loss:0.02887
# => Saving new checkpoint
# epoch [18/1001], MSE_loss:0.06469
# => Validation Accuracy did not improve
# epoch [19/1001], MSE_loss:0.07693
# => Validation Accuracy did not improve
# epoch [20/1001], MSE_loss:0.05379
# => Validation Accuracy did not improve
# epoch [21/1001], MSE_loss:0.01138
# => Saving new checkpoint
# epoch [22/1001], MSE_loss:0.07232
# => Validation Accuracy did not improve
# epoch [23/1001], MSE_loss:0.07129
# => Validation Accuracy did not improve
# epoch [24/1001], MSE_loss:0.06132
# => Validation Accuracy did not improve
# epoch [25/1001], MSE_loss:0.02997
# => Validation Accuracy did not improve
# epoch [26/1001], MSE_loss:0.01091
# => Saving new checkpoint
# epoch [27/1001], MSE_loss:0.02991
# => Validation Accuracy did not improve
# epoch [28/1001], MSE_loss:0.02891
# => Validation Accuracy did not improve
# epoch [29/1001], MSE_loss:0.01675
# => Validation Accuracy did not improve
# epoch [30/1001], MSE_loss:0.00565
# => Saving new checkpoint
# epoch [31/1001], MSE_loss:0.05768
# => Validation Accuracy did not improve
# epoch [32/1001], MSE_loss:0.02316
# => Validation Accuracy did not improve
# epoch [33/1001], MSE_loss:0.00563
# => Saving new checkpoint
# epoch [34/1001], MSE_loss:0.03987
# => Validation Accuracy did not improve
# epoch [35/1001], MSE_loss:0.03385
# => Validation Accuracy did not improve
# epoch [36/1001], MSE_loss:0.01131
# => Validation Accuracy did not improve
# epoch [37/1001], MSE_loss:0.04392
# => Validation Accuracy did not improve
# epoch [38/1001], MSE_loss:0.03118
# => Validation Accuracy did not improve
# epoch [39/1001], MSE_loss:0.03974
# => Validation Accuracy did not improve
# epoch [40/1001], MSE_loss:0.01105
# => Validation Accuracy did not improve
# epoch [41/1001], MSE_loss:0.03514
# => Validation Accuracy did not improve
# epoch [42/1001], MSE_loss:0.01071
# => Validation Accuracy did not improve
# epoch [43/1001], MSE_loss:0.01542
# => Validation Accuracy did not improve
# epoch [44/1001], MSE_loss:0.00949
# => Validation Accuracy did not improve
# epoch [45/1001], MSE_loss:0.02146
# => Validation Accuracy did not improve
# epoch [46/1001], MSE_loss:0.00777
# => Validation Accuracy did not improve
# epoch [47/1001], MSE_loss:0.00744
# => Validation Accuracy did not improve
# epoch [48/1001], MSE_loss:0.03984
# => Validation Accuracy did not improve
# epoch [49/1001], MSE_loss:0.02582
# => Validation Accuracy did not improve
# epoch [50/1001], MSE_loss:0.00818
# => Validation Accuracy did not improve
# epoch [51/1001], MSE_loss:0.01625
# => Validation Accuracy did not improve
# epoch [52/1001], MSE_loss:0.00413
# => Saving new checkpoint
# epoch [53/1001], MSE_loss:0.00477
# => Validation Accuracy did not improve
# epoch [54/1001], MSE_loss:0.01868
# => Validation Accuracy did not improve
# epoch [55/1001], MSE_loss:0.00906
# => Validation Accuracy did not improve
# epoch [56/1001], MSE_loss:0.00539
# => Validation Accuracy did not improve
# epoch [57/1001], MSE_loss:0.00882
# => Validation Accuracy did not improve
# epoch [58/1001], MSE_loss:0.00877
# => Validation Accuracy did not improve
# epoch [59/1001], MSE_loss:0.00678
# => Validation Accuracy did not improve
# epoch [60/1001], MSE_loss:0.00475
# => Validation Accuracy did not improve
# epoch [61/1001], MSE_loss:0.01861
# => Validation Accuracy did not improve
# epoch [62/1001], MSE_loss:0.00443
# => Validation Accuracy did not improve
# epoch [63/1001], MSE_loss:0.00533
# => Validation Accuracy did not improve
# epoch [64/1001], MSE_loss:0.01147
# => Validation Accuracy did not improve
# epoch [65/1001], MSE_loss:0.00525
# => Validation Accuracy did not improve
# epoch [66/1001], MSE_loss:0.00583
# => Validation Accuracy did not improve
# epoch [67/1001], MSE_loss:0.01169
# => Validation Accuracy did not improve
# epoch [68/1001], MSE_loss:0.00251
# => Saving new checkpoint
# epoch [69/1001], MSE_loss:0.00477
# => Validation Accuracy did not improve
# epoch [70/1001], MSE_loss:0.02250
# => Validation Accuracy did not improve
# epoch [71/1001], MSE_loss:0.00197
# => Saving new checkpoint
# epoch [72/1001], MSE_loss:0.00512
# => Validation Accuracy did not improve
# epoch [73/1001], MSE_loss:0.00408
# => Validation Accuracy did not improve
# epoch [74/1001], MSE_loss:0.01203
# => Validation Accuracy did not improve
# epoch [75/1001], MSE_loss:0.00338
# => Validation Accuracy did not improve
# epoch [76/1001], MSE_loss:0.00226
# => Validation Accuracy did not improve
# epoch [77/1001], MSE_loss:0.00257
# => Validation Accuracy did not improve
# epoch [78/1001], MSE_loss:0.00231
# => Validation Accuracy did not improve
# epoch [79/1001], MSE_loss:0.00324
# => Validation Accuracy did not improve
# epoch [80/1001], MSE_loss:0.00218
# => Validation Accuracy did not improve
# epoch [81/1001], MSE_loss:0.00264
# => Validation Accuracy did not improve
# epoch [82/1001], MSE_loss:0.00095
# => Saving new checkpoint
# epoch [83/1001], MSE_loss:0.00911
# => Validation Accuracy did not improve
# epoch [84/1001], MSE_loss:0.01336
# => Validation Accuracy did not improve
# epoch [85/1001], MSE_loss:0.00608
# => Validation Accuracy did not improve
# epoch [86/1001], MSE_loss:0.00738
# => Validation Accuracy did not improve
# epoch [87/1001], MSE_loss:0.00697
# => Validation Accuracy did not improve
# epoch [88/1001], MSE_loss:0.00256
# => Validation Accuracy did not improve
# epoch [89/1001], MSE_loss:0.00545
# => Validation Accuracy did not improve
# epoch [90/1001], MSE_loss:0.00252
# => Validation Accuracy did not improve
# epoch [91/1001], MSE_loss:0.00168
# => Validation Accuracy did not improve
# epoch [92/1001], MSE_loss:0.00247
# => Validation Accuracy did not improve
# epoch [93/1001], MSE_loss:0.00422
# => Validation Accuracy did not improve
# epoch [94/1001], MSE_loss:0.00906
# => Validation Accuracy did not improve
# epoch [95/1001], MSE_loss:0.00214
# => Validation Accuracy did not improve
# epoch [96/1001], MSE_loss:0.00511
# => Validation Accuracy did not improve
# epoch [97/1001], MSE_loss:0.00378
# => Validation Accuracy did not improve
# epoch [98/1001], MSE_loss:0.00352
# => Validation Accuracy did not improve
# epoch [99/1001], MSE_loss:0.00232
# => Validation Accuracy did not improve
# epoch [100/1001], MSE_loss:0.01039
# => Validation Accuracy did not improve
# epoch [101/1001], MSE_loss:0.00403
# => Validation Accuracy did not improve
# epoch [102/1001], MSE_loss:0.00214
# => Validation Accuracy did not improve
# epoch [103/1001], MSE_loss:0.00218
# => Validation Accuracy did not improve
# epoch [104/1001], MSE_loss:0.00309
# => Validation Accuracy did not improve
# epoch [105/1001], MSE_loss:0.00255
# => Validation Accuracy did not improve
# epoch [106/1001], MSE_loss:0.00240
# => Validation Accuracy did not improve
# epoch [107/1001], MSE_loss:0.00467
# => Validation Accuracy did not improve
# epoch [108/1001], MSE_loss:0.00383
# => Validation Accuracy did not improve
# epoch [109/1001], MSE_loss:0.01293
# => Validation Accuracy did not improve
# epoch [110/1001], MSE_loss:0.00070
# => Saving new checkpoint
# epoch [111/1001], MSE_loss:0.00281
# => Validation Accuracy did not improve
# epoch [112/1001], MSE_loss:0.00351
# => Validation Accuracy did not improve
# epoch [113/1001], MSE_loss:0.00182
# => Validation Accuracy did not improve
# epoch [114/1001], MSE_loss:0.00223
# => Validation Accuracy did not improve
# epoch [115/1001], MSE_loss:0.00136
# => Validation Accuracy did not improve
# epoch [116/1001], MSE_loss:0.00159
# => Validation Accuracy did not improve
# epoch [117/1001], MSE_loss:0.00584
# => Validation Accuracy did not improve
# epoch [118/1001], MSE_loss:0.00296
# => Validation Accuracy did not improve
# epoch [119/1001], MSE_loss:0.00198
# => Validation Accuracy did not improve
# epoch [120/1001], MSE_loss:0.00206
# => Validation Accuracy did not improve
# epoch [121/1001], MSE_loss:0.00124
# => Validation Accuracy did not improve
# epoch [122/1001], MSE_loss:0.00184
# => Validation Accuracy did not improve
# epoch [123/1001], MSE_loss:0.00567
# => Validation Accuracy did not improve
# epoch [124/1001], MSE_loss:0.00550
# => Validation Accuracy did not improve
# epoch [125/1001], MSE_loss:0.00518
# => Validation Accuracy did not improve
# epoch [126/1001], MSE_loss:0.00427
# => Validation Accuracy did not improve
# epoch [127/1001], MSE_loss:0.01152
# => Validation Accuracy did not improve
# epoch [128/1001], MSE_loss:0.00087
# => Validation Accuracy did not improve
# epoch [129/1001], MSE_loss:0.00749
# => Validation Accuracy did not improve
# epoch [130/1001], MSE_loss:0.00583
# => Validation Accuracy did not improve
# epoch [131/1001], MSE_loss:0.00205
# => Validation Accuracy did not improve
# epoch [132/1001], MSE_loss:0.00534
# => Validation Accuracy did not improve
# epoch [133/1001], MSE_loss:0.00299
# => Validation Accuracy did not improve
# epoch [134/1001], MSE_loss:0.00520
# => Validation Accuracy did not improve
# epoch [135/1001], MSE_loss:0.00026
# => Saving new checkpoint
# epoch [136/1001], MSE_loss:0.00338
# => Validation Accuracy did not improve
# epoch [137/1001], MSE_loss:0.00109
# => Validation Accuracy did not improve
# epoch [138/1001], MSE_loss:0.00398
# => Validation Accuracy did not improve
# epoch [139/1001], MSE_loss:0.00083
# => Validation Accuracy did not improve
# epoch [140/1001], MSE_loss:0.00373
# => Validation Accuracy did not improve
# epoch [141/1001], MSE_loss:0.00345
# => Validation Accuracy did not improve
# epoch [142/1001], MSE_loss:0.00198
# => Validation Accuracy did not improve
# epoch [143/1001], MSE_loss:0.00088
# => Validation Accuracy did not improve
# epoch [144/1001], MSE_loss:0.00103
# => Validation Accuracy did not improve
# epoch [145/1001], MSE_loss:0.00090
# => Validation Accuracy did not improve
# epoch [146/1001], MSE_loss:0.00423
# => Validation Accuracy did not improve
# epoch [147/1001], MSE_loss:0.00092
# => Validation Accuracy did not improve
# epoch [148/1001], MSE_loss:0.00092
# => Validation Accuracy did not improve
# epoch [149/1001], MSE_loss:0.00301
# => Validation Accuracy did not improve
# epoch [150/1001], MSE_loss:0.00026
# => Saving new checkpoint
# epoch [151/1001], MSE_loss:0.00154
# => Validation Accuracy did not improve
# epoch [152/1001], MSE_loss:0.00485
# => Validation Accuracy did not improve
# epoch [153/1001], MSE_loss:0.00097
# => Validation Accuracy did not improve
# epoch [154/1001], MSE_loss:0.00162
# => Validation Accuracy did not improve
# epoch [155/1001], MSE_loss:0.00230
# => Validation Accuracy did not improve
# epoch [156/1001], MSE_loss:0.01140
# => Validation Accuracy did not improve
# epoch [157/1001], MSE_loss:0.00299
# => Validation Accuracy did not improve
# epoch [158/1001], MSE_loss:0.00407
# => Validation Accuracy did not improve
# epoch [159/1001], MSE_loss:0.00265
# => Validation Accuracy did not improve
# epoch [160/1001], MSE_loss:0.00091
# => Validation Accuracy did not improve
# epoch [161/1001], MSE_loss:0.00289
# => Validation Accuracy did not improve
# epoch [162/1001], MSE_loss:0.00424
# => Validation Accuracy did not improve
# epoch [163/1001], MSE_loss:0.00091
# => Validation Accuracy did not improve
# epoch [164/1001], MSE_loss:0.00175
# => Validation Accuracy did not improve
# epoch [165/1001], MSE_loss:0.00374
# => Validation Accuracy did not improve
# epoch [166/1001], MSE_loss:0.00630
# => Validation Accuracy did not improve
# epoch [167/1001], MSE_loss:0.00388
# => Validation Accuracy did not improve
# epoch [168/1001], MSE_loss:0.00262
# => Validation Accuracy did not improve
# epoch [169/1001], MSE_loss:0.00020
# => Saving new checkpoint
# epoch [170/1001], MSE_loss:0.00383
# => Validation Accuracy did not improve
# epoch [171/1001], MSE_loss:0.00186
# => Validation Accuracy did not improve
# epoch [172/1001], MSE_loss:0.00446
# => Validation Accuracy did not improve
# epoch [173/1001], MSE_loss:0.00473
# => Validation Accuracy did not improve
# epoch [174/1001], MSE_loss:0.00138
# => Validation Accuracy did not improve
# epoch [175/1001], MSE_loss:0.00040
# => Validation Accuracy did not improve
# epoch [176/1001], MSE_loss:0.00171
# => Validation Accuracy did not improve
# epoch [177/1001], MSE_loss:0.00087
# => Validation Accuracy did not improve
# epoch [178/1001], MSE_loss:0.00275
# => Validation Accuracy did not improve
# epoch [179/1001], MSE_loss:0.00075
# => Validation Accuracy did not improve
# epoch [180/1001], MSE_loss:0.00432
# => Validation Accuracy did not improve
# epoch [181/1001], MSE_loss:0.00373
# => Validation Accuracy did not improve
# epoch [182/1001], MSE_loss:0.00222
# => Validation Accuracy did not improve
# epoch [183/1001], MSE_loss:0.00153
# => Validation Accuracy did not improve
# epoch [184/1001], MSE_loss:0.00183
# => Validation Accuracy did not improve
# epoch [185/1001], MSE_loss:0.00447
# => Validation Accuracy did not improve
# epoch [186/1001], MSE_loss:0.00173
# => Validation Accuracy did not improve
# epoch [187/1001], MSE_loss:0.00065
# => Validation Accuracy did not improve
# epoch [188/1001], MSE_loss:0.00137
# => Validation Accuracy did not improve
# epoch [189/1001], MSE_loss:0.00156
# => Validation Accuracy did not improve
# epoch [190/1001], MSE_loss:0.00022
# => Validation Accuracy did not improve
# epoch [191/1001], MSE_loss:0.00024
# => Validation Accuracy did not improve
# epoch [192/1001], MSE_loss:0.00254
# => Validation Accuracy did not improve
# epoch [193/1001], MSE_loss:0.01016
# => Validation Accuracy did not improve
# epoch [194/1001], MSE_loss:0.00233
# => Validation Accuracy did not improve
# epoch [195/1001], MSE_loss:0.00119
# => Validation Accuracy did not improve
# epoch [196/1001], MSE_loss:0.00089
# => Validation Accuracy did not improve
# epoch [197/1001], MSE_loss:0.00225
# => Validation Accuracy did not improve
# epoch [198/1001], MSE_loss:0.00331
# => Validation Accuracy did not improve
# epoch [199/1001], MSE_loss:0.00504
# => Validation Accuracy did not improve
# epoch [200/1001], MSE_loss:0.00217
# => Validation Accuracy did not improve
# epoch [201/1001], MSE_loss:0.00022
# => Validation Accuracy did not improve
# epoch [202/1001], MSE_loss:0.00155
# => Validation Accuracy did not improve
# epoch [203/1001], MSE_loss:0.00341
# => Validation Accuracy did not improve
# epoch [204/1001], MSE_loss:0.00287
# => Validation Accuracy did not improve
# epoch [205/1001], MSE_loss:0.00447
# => Validation Accuracy did not improve
# epoch [206/1001], MSE_loss:0.00334
# => Validation Accuracy did not improve
# epoch [207/1001], MSE_loss:0.00469
# => Validation Accuracy did not improve
# epoch [208/1001], MSE_loss:0.00477
# => Validation Accuracy did not improve
# epoch [209/1001], MSE_loss:0.00081
# => Validation Accuracy did not improve
# epoch [210/1001], MSE_loss:0.00140
# => Validation Accuracy did not improve
# epoch [211/1001], MSE_loss:0.00375
# => Validation Accuracy did not improve
# epoch [212/1001], MSE_loss:0.00123
# => Validation Accuracy did not improve
# epoch [213/1001], MSE_loss:0.00261
# => Validation Accuracy did not improve
# epoch [214/1001], MSE_loss:0.00142
# => Validation Accuracy did not improve
# epoch [215/1001], MSE_loss:0.00153
# => Validation Accuracy did not improve
# epoch [216/1001], MSE_loss:0.00156
# => Validation Accuracy did not improve
# epoch [217/1001], MSE_loss:0.00171
# => Validation Accuracy did not improve
# epoch [218/1001], MSE_loss:0.00453
# => Validation Accuracy did not improve
# epoch [219/1001], MSE_loss:0.00061
# => Validation Accuracy did not improve
# epoch [220/1001], MSE_loss:0.00150
# => Validation Accuracy did not improve
# epoch [221/1001], MSE_loss:0.00105
# => Validation Accuracy did not improve
# epoch [222/1001], MSE_loss:0.00019
# => Saving new checkpoint
# epoch [223/1001], MSE_loss:0.00402
# => Validation Accuracy did not improve
# epoch [224/1001], MSE_loss:0.00155
# => Validation Accuracy did not improve
# epoch [225/1001], MSE_loss:0.00411
# => Validation Accuracy did not improve
# epoch [226/1001], MSE_loss:0.00381
# => Validation Accuracy did not improve
# epoch [227/1001], MSE_loss:0.00129
# => Validation Accuracy did not improve
# epoch [228/1001], MSE_loss:0.00084
# => Validation Accuracy did not improve
# epoch [229/1001], MSE_loss:0.00561
# => Validation Accuracy did not improve
# epoch [230/1001], MSE_loss:0.00142
# => Validation Accuracy did not improve
# epoch [231/1001], MSE_loss:0.00028
# => Validation Accuracy did not improve
# epoch [232/1001], MSE_loss:0.00047
# => Validation Accuracy did not improve
# epoch [233/1001], MSE_loss:0.00219
# => Validation Accuracy did not improve
# epoch [234/1001], MSE_loss:0.00296
# => Validation Accuracy did not improve
# epoch [235/1001], MSE_loss:0.00153
# => Validation Accuracy did not improve
# epoch [236/1001], MSE_loss:0.00025
# => Validation Accuracy did not improve
# epoch [237/1001], MSE_loss:0.00185
# => Validation Accuracy did not improve
# epoch [238/1001], MSE_loss:0.00194
# => Validation Accuracy did not improve
# epoch [239/1001], MSE_loss:0.00064
# => Validation Accuracy did not improve
# epoch [240/1001], MSE_loss:0.00404
# => Validation Accuracy did not improve
# epoch [241/1001], MSE_loss:0.00065
# => Validation Accuracy did not improve
# epoch [242/1001], MSE_loss:0.00022
# => Validation Accuracy did not improve
# epoch [243/1001], MSE_loss:0.00263
# => Validation Accuracy did not improve
# epoch [244/1001], MSE_loss:0.00338
# => Validation Accuracy did not improve
# epoch [245/1001], MSE_loss:0.00069
# => Validation Accuracy did not improve
# epoch [246/1001], MSE_loss:0.00118
# => Validation Accuracy did not improve
# epoch [247/1001], MSE_loss:0.00486
# => Validation Accuracy did not improve
# epoch [248/1001], MSE_loss:0.00076
# => Validation Accuracy did not improve
# epoch [249/1001], MSE_loss:0.00323
# => Validation Accuracy did not improve
# epoch [250/1001], MSE_loss:0.00477
# => Validation Accuracy did not improve
# epoch [251/1001], MSE_loss:0.00250
# => Validation Accuracy did not improve
# epoch [252/1001], MSE_loss:0.00937
# => Validation Accuracy did not improve
# epoch [253/1001], MSE_loss:0.00402
# => Validation Accuracy did not improve
# epoch [254/1001], MSE_loss:0.00094
# => Validation Accuracy did not improve
# epoch [255/1001], MSE_loss:0.00102
# => Validation Accuracy did not improve
# epoch [256/1001], MSE_loss:0.00142
# => Validation Accuracy did not improve
# epoch [257/1001], MSE_loss:0.01257
# => Validation Accuracy did not improve
# epoch [258/1001], MSE_loss:0.00324
# => Validation Accuracy did not improve
# epoch [259/1001], MSE_loss:0.00118
# => Validation Accuracy did not improve
# epoch [260/1001], MSE_loss:0.00244
# => Validation Accuracy did not improve
# epoch [261/1001], MSE_loss:0.00164
# => Validation Accuracy did not improve
# epoch [262/1001], MSE_loss:0.00099
# => Validation Accuracy did not improve
# epoch [263/1001], MSE_loss:0.00087
# => Validation Accuracy did not improve
# epoch [264/1001], MSE_loss:0.00345
# => Validation Accuracy did not improve
# epoch [265/1001], MSE_loss:0.00568
# => Validation Accuracy did not improve
# epoch [266/1001], MSE_loss:0.00097
# => Validation Accuracy did not improve
# epoch [267/1001], MSE_loss:0.00356
# => Validation Accuracy did not improve
# epoch [268/1001], MSE_loss:0.00065
# => Validation Accuracy did not improve
# epoch [269/1001], MSE_loss:0.00375
# => Validation Accuracy did not improve
# epoch [270/1001], MSE_loss:0.00156
# => Validation Accuracy did not improve
# epoch [271/1001], MSE_loss:0.00338
# => Validation Accuracy did not improve
# epoch [272/1001], MSE_loss:0.00075
# => Validation Accuracy did not improve
# epoch [273/1001], MSE_loss:0.00381
# => Validation Accuracy did not improve
# epoch [274/1001], MSE_loss:0.00236
# => Validation Accuracy did not improve
# epoch [275/1001], MSE_loss:0.00045
# => Validation Accuracy did not improve
# epoch [276/1001], MSE_loss:0.00112
# => Validation Accuracy did not improve
# epoch [277/1001], MSE_loss:0.00375
# => Validation Accuracy did not improve
# epoch [278/1001], MSE_loss:0.00015
# => Saving new checkpoint
# epoch [279/1001], MSE_loss:0.00443
# => Validation Accuracy did not improve
# epoch [280/1001], MSE_loss:0.00151
# => Validation Accuracy did not improve
# epoch [281/1001], MSE_loss:0.00305
# => Validation Accuracy did not improve
# epoch [282/1001], MSE_loss:0.00386
# => Validation Accuracy did not improve
# epoch [283/1001], MSE_loss:0.00117
# => Validation Accuracy did not improve
# epoch [284/1001], MSE_loss:0.00171
# => Validation Accuracy did not improve
# epoch [285/1001], MSE_loss:0.00060
# => Validation Accuracy did not improve
# epoch [286/1001], MSE_loss:0.00061
# => Validation Accuracy did not improve
# epoch [287/1001], MSE_loss:0.00020
# => Validation Accuracy did not improve
# epoch [288/1001], MSE_loss:0.00098
# => Validation Accuracy did not improve
# epoch [289/1001], MSE_loss:0.00458
# => Validation Accuracy did not improve
# epoch [290/1001], MSE_loss:0.00242
# => Validation Accuracy did not improve
# epoch [291/1001], MSE_loss:0.00216
# => Validation Accuracy did not improve
# epoch [292/1001], MSE_loss:0.00069
# => Validation Accuracy did not improve
# epoch [293/1001], MSE_loss:0.00143
# => Validation Accuracy did not improve
# epoch [294/1001], MSE_loss:0.00083
# => Validation Accuracy did not improve
# epoch [295/1001], MSE_loss:0.00094
# => Validation Accuracy did not improve
# epoch [296/1001], MSE_loss:0.00166
# => Validation Accuracy did not improve
# epoch [297/1001], MSE_loss:0.00132
# => Validation Accuracy did not improve
# epoch [298/1001], MSE_loss:0.00109
# => Validation Accuracy did not improve
# epoch [299/1001], MSE_loss:0.00113
# => Validation Accuracy did not improve
# epoch [300/1001], MSE_loss:0.00231
# => Validation Accuracy did not improve
# epoch [301/1001], MSE_loss:0.00914
# => Validation Accuracy did not improve
# epoch [302/1001], MSE_loss:0.01229
# => Validation Accuracy did not improve
# epoch [303/1001], MSE_loss:0.00078
# => Validation Accuracy did not improve
# epoch [304/1001], MSE_loss:0.00220
# => Validation Accuracy did not improve
# epoch [305/1001], MSE_loss:0.00375
# => Validation Accuracy did not improve
# epoch [306/1001], MSE_loss:0.00019
# => Validation Accuracy did not improve
# epoch [307/1001], MSE_loss:0.00023
# => Validation Accuracy did not improve
# epoch [308/1001], MSE_loss:0.00317
# => Validation Accuracy did not improve
# epoch [309/1001], MSE_loss:0.00024
# => Validation Accuracy did not improve
# epoch [310/1001], MSE_loss:0.00062
# => Validation Accuracy did not improve
# epoch [311/1001], MSE_loss:0.00119
# => Validation Accuracy did not improve
# epoch [312/1001], MSE_loss:0.00096
# => Validation Accuracy did not improve
# epoch [313/1001], MSE_loss:0.00216
# => Validation Accuracy did not improve
# epoch [314/1001], MSE_loss:0.00091
# => Validation Accuracy did not improve
# epoch [315/1001], MSE_loss:0.00118
# => Validation Accuracy did not improve
# epoch [316/1001], MSE_loss:0.00211
# => Validation Accuracy did not improve
# epoch [317/1001], MSE_loss:0.00093
# => Validation Accuracy did not improve
# epoch [318/1001], MSE_loss:0.00416
# => Validation Accuracy did not improve
# epoch [319/1001], MSE_loss:0.00811
# => Validation Accuracy did not improve
# epoch [320/1001], MSE_loss:0.00385
# => Validation Accuracy did not improve
# epoch [321/1001], MSE_loss:0.00232
# => Validation Accuracy did not improve
# epoch [322/1001], MSE_loss:0.01147
# => Validation Accuracy did not improve
# epoch [323/1001], MSE_loss:0.00025
# => Validation Accuracy did not improve
# epoch [324/1001], MSE_loss:0.00153
# => Validation Accuracy did not improve
# epoch [325/1001], MSE_loss:0.00032
# => Validation Accuracy did not improve
# epoch [326/1001], MSE_loss:0.00476
# => Validation Accuracy did not improve
# epoch [327/1001], MSE_loss:0.00078
# => Validation Accuracy did not improve
# epoch [328/1001], MSE_loss:0.00124
# => Validation Accuracy did not improve
# epoch [329/1001], MSE_loss:0.00383
# => Validation Accuracy did not improve
# epoch [330/1001], MSE_loss:0.00446
# => Validation Accuracy did not improve
# epoch [331/1001], MSE_loss:0.00027
# => Validation Accuracy did not improve
# epoch [332/1001], MSE_loss:0.00033
# => Validation Accuracy did not improve
# epoch [333/1001], MSE_loss:0.00505
# => Validation Accuracy did not improve
# epoch [334/1001], MSE_loss:0.00323
# => Validation Accuracy did not improve
# epoch [335/1001], MSE_loss:0.00046
# => Validation Accuracy did not improve
# epoch [336/1001], MSE_loss:0.00067
# => Validation Accuracy did not improve
# epoch [337/1001], MSE_loss:0.00102
# => Validation Accuracy did not improve
# epoch [338/1001], MSE_loss:0.00076
# => Validation Accuracy did not improve
# epoch [339/1001], MSE_loss:0.00015
# => Validation Accuracy did not improve
# epoch [340/1001], MSE_loss:0.00099
# => Validation Accuracy did not improve
# epoch [341/1001], MSE_loss:0.00852
# => Validation Accuracy did not improve
# epoch [342/1001], MSE_loss:0.00044
# => Validation Accuracy did not improve
# epoch [343/1001], MSE_loss:0.00035
# => Validation Accuracy did not improve
# epoch [344/1001], MSE_loss:0.00025
# => Validation Accuracy did not improve
# epoch [345/1001], MSE_loss:0.00064
# => Validation Accuracy did not improve
# epoch [346/1001], MSE_loss:0.00024
# => Validation Accuracy did not improve
# epoch [347/1001], MSE_loss:0.00092
# => Validation Accuracy did not improve
# epoch [348/1001], MSE_loss:0.00246
# => Validation Accuracy did not improve
# epoch [349/1001], MSE_loss:0.00124
# => Validation Accuracy did not improve
# epoch [350/1001], MSE_loss:0.00147
# => Validation Accuracy did not improve
# epoch [351/1001], MSE_loss:0.00068
# => Validation Accuracy did not improve
# epoch [352/1001], MSE_loss:0.00353
# => Validation Accuracy did not improve
# epoch [353/1001], MSE_loss:0.00315
# => Validation Accuracy did not improve
# epoch [354/1001], MSE_loss:0.00545
# => Validation Accuracy did not improve
# epoch [355/1001], MSE_loss:0.00142
# => Validation Accuracy did not improve
# epoch [356/1001], MSE_loss:0.00447
# => Validation Accuracy did not improve
# epoch [357/1001], MSE_loss:0.00109
# => Validation Accuracy did not improve
# epoch [358/1001], MSE_loss:0.00087
# => Validation Accuracy did not improve
# epoch [359/1001], MSE_loss:0.00307
# => Validation Accuracy did not improve
# epoch [360/1001], MSE_loss:0.00050
# => Validation Accuracy did not improve
# epoch [361/1001], MSE_loss:0.00027
# => Validation Accuracy did not improve
# epoch [362/1001], MSE_loss:0.00334
# => Validation Accuracy did not improve
# epoch [363/1001], MSE_loss:0.00108
# => Validation Accuracy did not improve
# epoch [364/1001], MSE_loss:0.00017
# => Validation Accuracy did not improve
# epoch [365/1001], MSE_loss:0.00127
# => Validation Accuracy did not improve
# epoch [366/1001], MSE_loss:0.00056
# => Validation Accuracy did not improve
# epoch [367/1001], MSE_loss:0.00115
# => Validation Accuracy did not improve
# epoch [368/1001], MSE_loss:0.00115
# => Validation Accuracy did not improve
# epoch [369/1001], MSE_loss:0.00054
# => Validation Accuracy did not improve
# epoch [370/1001], MSE_loss:0.00140
# => Validation Accuracy did not improve
# epoch [371/1001], MSE_loss:0.00156
# => Validation Accuracy did not improve
# epoch [372/1001], MSE_loss:0.00055
# => Validation Accuracy did not improve
# epoch [373/1001], MSE_loss:0.00053
# => Validation Accuracy did not improve
# epoch [374/1001], MSE_loss:0.00292
# => Validation Accuracy did not improve
# epoch [375/1001], MSE_loss:0.00488
# => Validation Accuracy did not improve
# epoch [376/1001], MSE_loss:0.00071
# => Validation Accuracy did not improve
# epoch [377/1001], MSE_loss:0.00392
# => Validation Accuracy did not improve
# epoch [378/1001], MSE_loss:0.00209
# => Validation Accuracy did not improve
# epoch [379/1001], MSE_loss:0.00443
# => Validation Accuracy did not improve
# epoch [380/1001], MSE_loss:0.00154
# => Validation Accuracy did not improve
# epoch [381/1001], MSE_loss:0.00028
# => Validation Accuracy did not improve
# epoch [382/1001], MSE_loss:0.00095
# => Validation Accuracy did not improve
# epoch [383/1001], MSE_loss:0.00415
# => Validation Accuracy did not improve
# epoch [384/1001], MSE_loss:0.00101
# => Validation Accuracy did not improve
# epoch [385/1001], MSE_loss:0.00045
# => Validation Accuracy did not improve
# epoch [386/1001], MSE_loss:0.00094
# => Validation Accuracy did not improve
# epoch [387/1001], MSE_loss:0.00137
# => Validation Accuracy did not improve
# epoch [388/1001], MSE_loss:0.00062
# => Validation Accuracy did not improve
# epoch [389/1001], MSE_loss:0.00227
# => Validation Accuracy did not improve
# epoch [390/1001], MSE_loss:0.00224
# => Validation Accuracy did not improve
# epoch [391/1001], MSE_loss:0.00173
# => Validation Accuracy did not improve
# epoch [392/1001], MSE_loss:0.00913
# => Validation Accuracy did not improve
# epoch [393/1001], MSE_loss:0.00442
# => Validation Accuracy did not improve
# epoch [394/1001], MSE_loss:0.00077
# => Validation Accuracy did not improve
# epoch [395/1001], MSE_loss:0.00177
# => Validation Accuracy did not improve
# epoch [396/1001], MSE_loss:0.00387
# => Validation Accuracy did not improve
# epoch [397/1001], MSE_loss:0.00223
# => Validation Accuracy did not improve
# epoch [398/1001], MSE_loss:0.00020
# => Validation Accuracy did not improve
# epoch [399/1001], MSE_loss:0.00142
# => Validation Accuracy did not improve
# epoch [400/1001], MSE_loss:0.00219
# => Validation Accuracy did not improve
# epoch [401/1001], MSE_loss:0.00068
# => Validation Accuracy did not improve
# epoch [402/1001], MSE_loss:0.00222
# => Validation Accuracy did not improve
# epoch [403/1001], MSE_loss:0.00469
# => Validation Accuracy did not improve
# epoch [404/1001], MSE_loss:0.00156
# => Validation Accuracy did not improve
# epoch [405/1001], MSE_loss:0.00203
# => Validation Accuracy did not improve
# epoch [406/1001], MSE_loss:0.00105
# => Validation Accuracy did not improve
# epoch [407/1001], MSE_loss:0.00119
# => Validation Accuracy did not improve
# epoch [408/1001], MSE_loss:0.00519
# => Validation Accuracy did not improve
# epoch [409/1001], MSE_loss:0.00074
# => Validation Accuracy did not improve
# epoch [410/1001], MSE_loss:0.00206
# => Validation Accuracy did not improve
# epoch [411/1001], MSE_loss:0.00315
# => Validation Accuracy did not improve
# epoch [412/1001], MSE_loss:0.00102
# => Validation Accuracy did not improve
# epoch [413/1001], MSE_loss:0.00024
# => Validation Accuracy did not improve
# epoch [414/1001], MSE_loss:0.00447
# => Validation Accuracy did not improve
# epoch [415/1001], MSE_loss:0.00374
# => Validation Accuracy did not improve
# epoch [416/1001], MSE_loss:0.00054
# => Validation Accuracy did not improve
# epoch [417/1001], MSE_loss:0.00066
# => Validation Accuracy did not improve
# epoch [418/1001], MSE_loss:0.00108
# => Validation Accuracy did not improve
# epoch [419/1001], MSE_loss:0.00275
# => Validation Accuracy did not improve
# epoch [420/1001], MSE_loss:0.00236
# => Validation Accuracy did not improve
# epoch [421/1001], MSE_loss:0.00496
# => Validation Accuracy did not improve
# epoch [422/1001], MSE_loss:0.00072
# => Validation Accuracy did not improve
# epoch [423/1001], MSE_loss:0.00488
# => Validation Accuracy did not improve
# epoch [424/1001], MSE_loss:0.00091
# => Validation Accuracy did not improve
# epoch [425/1001], MSE_loss:0.00206
# => Validation Accuracy did not improve
# epoch [426/1001], MSE_loss:0.00376
# => Validation Accuracy did not improve
# epoch [427/1001], MSE_loss:0.00022
# => Validation Accuracy did not improve
# epoch [428/1001], MSE_loss:0.00071
# => Validation Accuracy did not improve
# epoch [429/1001], MSE_loss:0.00112
# => Validation Accuracy did not improve
# epoch [430/1001], MSE_loss:0.00286
# => Validation Accuracy did not improve
# epoch [431/1001], MSE_loss:0.00060
# => Validation Accuracy did not improve
# epoch [432/1001], MSE_loss:0.00329
# => Validation Accuracy did not improve
# epoch [433/1001], MSE_loss:0.00852
# => Validation Accuracy did not improve
# epoch [434/1001], MSE_loss:0.00372
# => Validation Accuracy did not improve
# epoch [435/1001], MSE_loss:0.00323
# => Validation Accuracy did not improve
# epoch [436/1001], MSE_loss:0.00153
# => Validation Accuracy did not improve
# epoch [437/1001], MSE_loss:0.00379
# => Validation Accuracy did not improve
# epoch [438/1001], MSE_loss:0.00192
# => Validation Accuracy did not improve
# epoch [439/1001], MSE_loss:0.00150
# => Validation Accuracy did not improve
# epoch [440/1001], MSE_loss:0.00019
# => Validation Accuracy did not improve
# epoch [441/1001], MSE_loss:0.00897
# => Validation Accuracy did not improve
# epoch [442/1001], MSE_loss:0.00098
# => Validation Accuracy did not improve
# epoch [443/1001], MSE_loss:0.00234
# => Validation Accuracy did not improve
# epoch [444/1001], MSE_loss:0.00035
# => Validation Accuracy did not improve
# epoch [445/1001], MSE_loss:0.00101
# => Validation Accuracy did not improve
# epoch [446/1001], MSE_loss:0.00367
# => Validation Accuracy did not improve
# epoch [447/1001], MSE_loss:0.00307
# => Validation Accuracy did not improve
# epoch [448/1001], MSE_loss:0.00033
# => Validation Accuracy did not improve
# epoch [449/1001], MSE_loss:0.00142
# => Validation Accuracy did not improve
# epoch [450/1001], MSE_loss:0.00080
# => Validation Accuracy did not improve
# epoch [451/1001], MSE_loss:0.00310
# => Validation Accuracy did not improve
# epoch [452/1001], MSE_loss:0.00065
# => Validation Accuracy did not improve
# epoch [453/1001], MSE_loss:0.00229
# => Validation Accuracy did not improve
# epoch [454/1001], MSE_loss:0.00207
# => Validation Accuracy did not improve
# epoch [455/1001], MSE_loss:0.00076
# => Validation Accuracy did not improve
# epoch [456/1001], MSE_loss:0.00074
# => Validation Accuracy did not improve
# epoch [457/1001], MSE_loss:0.00066
# => Validation Accuracy did not improve
# epoch [458/1001], MSE_loss:0.00930
# => Validation Accuracy did not improve
# epoch [459/1001], MSE_loss:0.00196
# => Validation Accuracy did not improve
# epoch [460/1001], MSE_loss:0.00375
# => Validation Accuracy did not improve
# epoch [461/1001], MSE_loss:0.00223
# => Validation Accuracy did not improve
# epoch [462/1001], MSE_loss:0.00344
# => Validation Accuracy did not improve
# epoch [463/1001], MSE_loss:0.00323
# => Validation Accuracy did not improve
# epoch [464/1001], MSE_loss:0.00094
# => Validation Accuracy did not improve
# epoch [465/1001], MSE_loss:0.00088
# => Validation Accuracy did not improve
# epoch [466/1001], MSE_loss:0.00083
# => Validation Accuracy did not improve
# epoch [467/1001], MSE_loss:0.00334
# => Validation Accuracy did not improve
# epoch [468/1001], MSE_loss:0.00346
# => Validation Accuracy did not improve
# epoch [469/1001], MSE_loss:0.00192
# => Validation Accuracy did not improve
# epoch [470/1001], MSE_loss:0.00192
# => Validation Accuracy did not improve
# epoch [471/1001], MSE_loss:0.00341
# => Validation Accuracy did not improve
# epoch [472/1001], MSE_loss:0.00334
# => Validation Accuracy did not improve
# epoch [473/1001], MSE_loss:0.00075
# => Validation Accuracy did not improve
# epoch [474/1001], MSE_loss:0.00232
# => Validation Accuracy did not improve
# epoch [475/1001], MSE_loss:0.00092
# => Validation Accuracy did not improve
# epoch [476/1001], MSE_loss:0.00488
# => Validation Accuracy did not improve
# epoch [477/1001], MSE_loss:0.00372
# => Validation Accuracy did not improve
# epoch [478/1001], MSE_loss:0.00118
# => Validation Accuracy did not improve
# epoch [479/1001], MSE_loss:0.00219
# => Validation Accuracy did not improve
# epoch [480/1001], MSE_loss:0.00416
# => Validation Accuracy did not improve
# epoch [481/1001], MSE_loss:0.00024
# => Validation Accuracy did not improve
# epoch [482/1001], MSE_loss:0.00930
# => Validation Accuracy did not improve
# epoch [483/1001], MSE_loss:0.00329
# => Validation Accuracy did not improve
# epoch [484/1001], MSE_loss:0.00353
# => Validation Accuracy did not improve
# epoch [485/1001], MSE_loss:0.00312
# => Validation Accuracy did not improve
# epoch [486/1001], MSE_loss:0.00044
# => Validation Accuracy did not improve
# epoch [487/1001], MSE_loss:0.00444
# => Validation Accuracy did not improve
# epoch [488/1001], MSE_loss:0.00144
# => Validation Accuracy did not improve
# epoch [489/1001], MSE_loss:0.00194
# => Validation Accuracy did not improve
# epoch [490/1001], MSE_loss:0.00046
# => Validation Accuracy did not improve
# epoch [491/1001], MSE_loss:0.00048
# => Validation Accuracy did not improve
# epoch [492/1001], MSE_loss:0.00219
# => Validation Accuracy did not improve
# epoch [493/1001], MSE_loss:0.00054
# => Validation Accuracy did not improve
# epoch [494/1001], MSE_loss:0.00264
# => Validation Accuracy did not improve
# epoch [495/1001], MSE_loss:0.00669
# => Validation Accuracy did not improve
# epoch [496/1001], MSE_loss:0.00085
# => Validation Accuracy did not improve
# epoch [497/1001], MSE_loss:0.00063
# => Validation Accuracy did not improve
# epoch [498/1001], MSE_loss:0.00140
# => Validation Accuracy did not improve
# epoch [499/1001], MSE_loss:0.00557
# => Validation Accuracy did not improve
# epoch [500/1001], MSE_loss:0.00075
# => Validation Accuracy did not improve
# epoch [501/1001], MSE_loss:0.00127
# => Validation Accuracy did not improve
# epoch [502/1001], MSE_loss:0.00067
# => Validation Accuracy did not improve
# epoch [503/1001], MSE_loss:0.00024
# => Validation Accuracy did not improve
# epoch [504/1001], MSE_loss:0.00071
# => Validation Accuracy did not improve
# epoch [505/1001], MSE_loss:0.00112
# => Validation Accuracy did not improve
# epoch [506/1001], MSE_loss:0.00334
# => Validation Accuracy did not improve
# epoch [507/1001], MSE_loss:0.00085
# => Validation Accuracy did not improve
# epoch [508/1001], MSE_loss:0.00049
# => Validation Accuracy did not improve
# epoch [509/1001], MSE_loss:0.00061
# => Validation Accuracy did not improve
# epoch [510/1001], MSE_loss:0.00118
# => Validation Accuracy did not improve
# epoch [511/1001], MSE_loss:0.00383
# => Validation Accuracy did not improve
# epoch [512/1001], MSE_loss:0.00027
# => Validation Accuracy did not improve
# epoch [513/1001], MSE_loss:0.00307
# => Validation Accuracy did not improve
# epoch [514/1001], MSE_loss:0.00095
# => Validation Accuracy did not improve
# epoch [515/1001], MSE_loss:0.00035
# => Validation Accuracy did not improve
# epoch [516/1001], MSE_loss:0.00094
# => Validation Accuracy did not improve
# epoch [517/1001], MSE_loss:0.00076
# => Validation Accuracy did not improve
# epoch [518/1001], MSE_loss:0.00244
# => Validation Accuracy did not improve
# epoch [519/1001], MSE_loss:0.00021
# => Validation Accuracy did not improve
# epoch [520/1001], MSE_loss:0.00032
# => Validation Accuracy did not improve
# epoch [521/1001], MSE_loss:0.00307
# => Validation Accuracy did not improve
# epoch [522/1001], MSE_loss:0.00070
# => Validation Accuracy did not improve
# epoch [523/1001], MSE_loss:0.00083
# => Validation Accuracy did not improve
# epoch [524/1001], MSE_loss:0.00033
# => Validation Accuracy did not improve
# epoch [525/1001], MSE_loss:0.00278
# => Validation Accuracy did not improve
# epoch [526/1001], MSE_loss:0.00307
# => Validation Accuracy did not improve
# epoch [527/1001], MSE_loss:0.00124
# => Validation Accuracy did not improve
# epoch [528/1001], MSE_loss:0.00339
# => Validation Accuracy did not improve
# epoch [529/1001], MSE_loss:0.00066
# => Validation Accuracy did not improve
# epoch [530/1001], MSE_loss:0.00986
# => Validation Accuracy did not improve
# epoch [531/1001], MSE_loss:0.00545
# => Validation Accuracy did not improve
# epoch [532/1001], MSE_loss:0.00068
# => Validation Accuracy did not improve
# epoch [533/1001], MSE_loss:0.00359
# => Validation Accuracy did not improve
# epoch [534/1001], MSE_loss:0.00022
# => Validation Accuracy did not improve
# epoch [535/1001], MSE_loss:0.00062
# => Validation Accuracy did not improve
# epoch [536/1001], MSE_loss:0.00376
# => Validation Accuracy did not improve
# epoch [537/1001], MSE_loss:0.00066
# => Validation Accuracy did not improve
# epoch [538/1001], MSE_loss:0.00067
# => Validation Accuracy did not improve
# epoch [539/1001], MSE_loss:0.00411
# => Validation Accuracy did not improve
# epoch [540/1001], MSE_loss:0.00032
# => Validation Accuracy did not improve
# epoch [541/1001], MSE_loss:0.00058
# => Validation Accuracy did not improve
# epoch [542/1001], MSE_loss:0.00244
# => Validation Accuracy did not improve
# epoch [543/1001], MSE_loss:0.00477
# => Validation Accuracy did not improve
# epoch [544/1001], MSE_loss:0.00103
# => Validation Accuracy did not improve
# epoch [545/1001], MSE_loss:0.00125
# => Validation Accuracy did not improve
# epoch [546/1001], MSE_loss:0.00378
# => Validation Accuracy did not improve
# epoch [547/1001], MSE_loss:0.00081
# => Validation Accuracy did not improve
# epoch [548/1001], MSE_loss:0.01089
# => Validation Accuracy did not improve
# epoch [549/1001], MSE_loss:0.00195
# => Validation Accuracy did not improve
# epoch [550/1001], MSE_loss:0.00225
# => Validation Accuracy did not improve
# epoch [551/1001], MSE_loss:0.00083
# => Validation Accuracy did not improve
# epoch [552/1001], MSE_loss:0.00169
# => Validation Accuracy did not improve
# epoch [553/1001], MSE_loss:0.00071
# => Validation Accuracy did not improve
# epoch [554/1001], MSE_loss:0.00105
# => Validation Accuracy did not improve
# epoch [555/1001], MSE_loss:0.00519
# => Validation Accuracy did not improve
# epoch [556/1001], MSE_loss:0.00081
# => Validation Accuracy did not improve
# epoch [557/1001], MSE_loss:0.00143
# => Validation Accuracy did not improve
# epoch [558/1001], MSE_loss:0.00355
# => Validation Accuracy did not improve
# epoch [559/1001], MSE_loss:0.00176
# => Validation Accuracy did not improve
# epoch [560/1001], MSE_loss:0.00374
# => Validation Accuracy did not improve
# epoch [561/1001], MSE_loss:0.00353
# => Validation Accuracy did not improve
# epoch [562/1001], MSE_loss:0.00357
# => Validation Accuracy did not improve
# epoch [563/1001], MSE_loss:0.00019
# => Validation Accuracy did not improve
# epoch [564/1001], MSE_loss:0.00126
# => Validation Accuracy did not improve
# epoch [565/1001], MSE_loss:0.00914
# => Validation Accuracy did not improve
# epoch [566/1001], MSE_loss:0.00892
# => Validation Accuracy did not improve
# epoch [567/1001], MSE_loss:0.00328
# => Validation Accuracy did not improve
# epoch [568/1001], MSE_loss:0.00231
# => Validation Accuracy did not improve
# epoch [569/1001], MSE_loss:0.00115
# => Validation Accuracy did not improve
# epoch [570/1001], MSE_loss:0.00320
# => Validation Accuracy did not improve
# epoch [571/1001], MSE_loss:0.00402
# => Validation Accuracy did not improve
# epoch [572/1001], MSE_loss:0.00019
# => Validation Accuracy did not improve
# epoch [573/1001], MSE_loss:0.00278
# => Validation Accuracy did not improve
# epoch [574/1001], MSE_loss:0.00386
# => Validation Accuracy did not improve
# epoch [575/1001], MSE_loss:0.00193
# => Validation Accuracy did not improve
# epoch [576/1001], MSE_loss:0.00316
# => Validation Accuracy did not improve
# epoch [577/1001], MSE_loss:0.00265
# => Validation Accuracy did not improve
# epoch [578/1001], MSE_loss:0.00207
# => Validation Accuracy did not improve
# epoch [579/1001], MSE_loss:0.00120
# => Validation Accuracy did not improve
# epoch [580/1001], MSE_loss:0.00234
# => Validation Accuracy did not improve
# epoch [581/1001], MSE_loss:0.00307
# => Validation Accuracy did not improve
# epoch [582/1001], MSE_loss:0.00086
# => Validation Accuracy did not improve
# epoch [583/1001], MSE_loss:0.00339
# => Validation Accuracy did not improve
# epoch [584/1001], MSE_loss:0.00170
# => Validation Accuracy did not improve
# epoch [585/1001], MSE_loss:0.00346
# => Validation Accuracy did not improve
# epoch [586/1001], MSE_loss:0.00020
# => Validation Accuracy did not improve
# epoch [587/1001], MSE_loss:0.00099
# => Validation Accuracy did not improve
# epoch [588/1001], MSE_loss:0.00101
# => Validation Accuracy did not improve
# epoch [589/1001], MSE_loss:0.00107
# => Validation Accuracy did not improve
# epoch [590/1001], MSE_loss:0.00092
# => Validation Accuracy did not improve
# epoch [591/1001], MSE_loss:0.00477
# => Validation Accuracy did not improve
# epoch [592/1001], MSE_loss:0.00021
# => Validation Accuracy did not improve
# epoch [593/1001], MSE_loss:0.00378
# => Validation Accuracy did not improve
# epoch [594/1001], MSE_loss:0.00232
# => Validation Accuracy did not improve
# epoch [595/1001], MSE_loss:0.00061
# => Validation Accuracy did not improve
# epoch [596/1001], MSE_loss:0.00460
# => Validation Accuracy did not improve
# epoch [597/1001], MSE_loss:0.01089
# => Validation Accuracy did not improve
# epoch [598/1001], MSE_loss:0.00023
# => Validation Accuracy did not improve
# epoch [599/1001], MSE_loss:0.00374
# => Validation Accuracy did not improve
# epoch [600/1001], MSE_loss:0.00460
# => Validation Accuracy did not improve
# epoch [601/1001], MSE_loss:0.00378
# => Validation Accuracy did not improve
# epoch [602/1001], MSE_loss:0.00378
# => Validation Accuracy did not improve
# epoch [603/1001], MSE_loss:0.00082
# => Validation Accuracy did not improve
# epoch [604/1001], MSE_loss:0.00096
# => Validation Accuracy did not improve
# epoch [605/1001], MSE_loss:0.00057
# => Validation Accuracy did not improve
# epoch [606/1001], MSE_loss:0.00066
# => Validation Accuracy did not improve
# epoch [607/1001], MSE_loss:0.00091
# => Validation Accuracy did not improve
# epoch [608/1001], MSE_loss:0.00027
# => Validation Accuracy did not improve
# epoch [609/1001], MSE_loss:0.00329
# => Validation Accuracy did not improve
# epoch [610/1001], MSE_loss:0.00453
# => Validation Accuracy did not improve
# epoch [611/1001], MSE_loss:0.00172
# => Validation Accuracy did not improve
# epoch [612/1001], MSE_loss:0.00353
# => Validation Accuracy did not improve
# epoch [613/1001], MSE_loss:0.00123
# => Validation Accuracy did not improve
# epoch [614/1001], MSE_loss:0.00202
# => Validation Accuracy did not improve
# epoch [615/1001], MSE_loss:0.00086
# => Validation Accuracy did not improve
# epoch [616/1001], MSE_loss:0.00172
# => Validation Accuracy did not improve
# epoch [617/1001], MSE_loss:0.00166
# => Validation Accuracy did not improve
# epoch [618/1001], MSE_loss:0.00119
# => Validation Accuracy did not improve
# epoch [619/1001], MSE_loss:0.00332
# => Validation Accuracy did not improve
# epoch [620/1001], MSE_loss:0.00060
# => Validation Accuracy did not improve
# epoch [621/1001], MSE_loss:0.00568
# => Validation Accuracy did not improve
# epoch [622/1001], MSE_loss:0.01229
# => Validation Accuracy did not improve
# epoch [623/1001], MSE_loss:0.00148
# => Validation Accuracy did not improve
# epoch [624/1001], MSE_loss:0.00105
# => Validation Accuracy did not improve
# epoch [625/1001], MSE_loss:0.00064
# => Validation Accuracy did not improve
# epoch [626/1001], MSE_loss:0.00387
# => Validation Accuracy did not improve
# epoch [627/1001], MSE_loss:0.00029
# => Validation Accuracy did not improve
# epoch [628/1001], MSE_loss:0.00467
# => Validation Accuracy did not improve
# epoch [629/1001], MSE_loss:0.00469
# => Validation Accuracy did not improve
# epoch [630/1001], MSE_loss:0.00516
# => Validation Accuracy did not improve
# epoch [631/1001], MSE_loss:0.00256
# => Validation Accuracy did not improve
# epoch [632/1001], MSE_loss:0.00058
# => Validation Accuracy did not improve
# epoch [633/1001], MSE_loss:0.00032
# => Validation Accuracy did not improve
# epoch [634/1001], MSE_loss:0.00030
# => Validation Accuracy did not improve
# epoch [635/1001], MSE_loss:0.00149
# => Validation Accuracy did not improve
# epoch [636/1001], MSE_loss:0.00133
# => Validation Accuracy did not improve
# epoch [637/1001], MSE_loss:0.01229
# => Validation Accuracy did not improve
# epoch [638/1001], MSE_loss:0.00084
# => Validation Accuracy did not improve
# epoch [639/1001], MSE_loss:0.00112
# => Validation Accuracy did not improve
# epoch [640/1001], MSE_loss:0.00105
# => Validation Accuracy did not improve
# epoch [641/1001], MSE_loss:0.00043
# => Validation Accuracy did not improve
# epoch [642/1001], MSE_loss:0.00194
# => Validation Accuracy did not improve
# epoch [643/1001], MSE_loss:0.00385
# => Validation Accuracy did not improve
# epoch [644/1001], MSE_loss:0.00838
# => Validation Accuracy did not improve
# epoch [645/1001], MSE_loss:0.00075
# => Validation Accuracy did not improve
# epoch [646/1001], MSE_loss:0.00101
# => Validation Accuracy did not improve
# epoch [647/1001], MSE_loss:0.00060
# => Validation Accuracy did not improve
# epoch [648/1001], MSE_loss:0.00394
# => Validation Accuracy did not improve
# epoch [649/1001], MSE_loss:0.00202
# => Validation Accuracy did not improve
# epoch [650/1001], MSE_loss:0.00434
# => Validation Accuracy did not improve
# epoch [651/1001], MSE_loss:0.00103
# => Validation Accuracy did not improve
# epoch [652/1001], MSE_loss:0.00115
# => Validation Accuracy did not improve
# epoch [653/1001], MSE_loss:0.00232
# => Validation Accuracy did not improve
# epoch [654/1001], MSE_loss:0.00447
# => Validation Accuracy did not improve
# ...
# epoch [786/1001], MSE_loss:0.00396
# => Validation Accuracy did not improve
# epoch [787/1001], MSE_loss:0.00237
# => Validation Accuracy did not improve
# epoch [788/1001], MSE_loss:0.00069
# => Validation Accuracy did not improve
# epoch [789/1001], MSE_loss:0.00111
# => Validation Accuracy did not improve
# epoch [790/1001], MSE_loss:0.00219
# => Validation Accuracy did not improve
# epoch [791/1001], MSE_loss:0.00124
# => Validation Accuracy did not improve
# epoch [792/1001], MSE_loss:0.00222
# => Validation Accuracy did not improve
# epoch [793/1001], MSE_loss:0.00231
# => Validation Accuracy did not improve
# epoch [794/1001], MSE_loss:0.00250
# => Validation Accuracy did not improve
# epoch [795/1001], MSE_loss:0.00049
# => Validation Accuracy did not improve
# epoch [796/1001], MSE_loss:0.00111
# => Validation Accuracy did not improve
# epoch [797/1001], MSE_loss:0.00272
# => Validation Accuracy did not improve
# epoch [798/1001], MSE_loss:0.00192
# => Validation Accuracy did not improve
# epoch [799/1001], MSE_loss:0.00313
# => Validation Accuracy did not improve
# epoch [800/1001], MSE_loss:0.00060
# => Validation Accuracy did not improve
# epoch [801/1001], MSE_loss:0.00125
# => Validation Accuracy did not improve
# epoch [802/1001], MSE_loss:0.00213
# => Validation Accuracy did not improve
# epoch [803/1001], MSE_loss:0.00071
# => Validation Accuracy did not improve
# epoch [804/1001], MSE_loss:0.00986
# => Validation Accuracy did not improve
# epoch [805/1001], MSE_loss:0.00295
# => Validation Accuracy did not improve
# epoch [806/1001], MSE_loss:0.00353
# => Validation Accuracy did not improve
# epoch [807/1001], MSE_loss:0.00320
# => Validation Accuracy did not improve
# epoch [808/1001], MSE_loss:0.00367
# => Validation Accuracy did not improve
# epoch [809/1001], MSE_loss:0.00323
# => Validation Accuracy did not improve
# epoch [810/1001], MSE_loss:0.00359
# => Validation Accuracy did not improve
# epoch [811/1001], MSE_loss:0.00515
# => Validation Accuracy did not improve
# epoch [812/1001], MSE_loss:0.00149
# => Validation Accuracy did not improve
# epoch [813/1001], MSE_loss:0.00121
# => Validation Accuracy did not improve
# epoch [814/1001], MSE_loss:0.00595
# => Validation Accuracy did not improve
# epoch [815/1001], MSE_loss:0.00057
# => Validation Accuracy did not improve
# epoch [816/1001], MSE_loss:0.00097
# => Validation Accuracy did not improve
# epoch [817/1001], MSE_loss:0.00811
# => Validation Accuracy did not improve
# epoch [818/1001], MSE_loss:0.00200
# => Validation Accuracy did not improve
# epoch [819/1001], MSE_loss:0.00378
# => Validation Accuracy did not improve
# epoch [820/1001], MSE_loss:0.00367
# => Validation Accuracy did not improve
# epoch [821/1001], MSE_loss:0.00569
# => Validation Accuracy did not improve
# epoch [822/1001], MSE_loss:0.00356
# => Validation Accuracy did not improve
# epoch [823/1001], MSE_loss:0.00183
# => Validation Accuracy did not improve
# epoch [824/1001], MSE_loss:0.00150
# => Validation Accuracy did not improve
# epoch [825/1001], MSE_loss:0.00214
# => Validation Accuracy did not improve
# epoch [826/1001], MSE_loss:0.00207
# => Validation Accuracy did not improve
# epoch [827/1001], MSE_loss:0.00071
# => Validation Accuracy did not improve
# epoch [828/1001], MSE_loss:0.00154
# => Validation Accuracy did not improve
# epoch [829/1001], MSE_loss:0.00072
# => Validation Accuracy did not improve
# epoch [830/1001], MSE_loss:0.00146
# => Validation Accuracy did not improve
# epoch [831/1001], MSE_loss:0.00381
# => Validation Accuracy did not improve
# epoch [832/1001], MSE_loss:0.00074
# => Validation Accuracy did not improve
# epoch [833/1001], MSE_loss:0.00053
# => Validation Accuracy did not improve
# epoch [834/1001], MSE_loss:0.00324
# => Validation Accuracy did not improve
# epoch [835/1001], MSE_loss:0.00142
# => Validation Accuracy did not improve
# epoch [836/1001], MSE_loss:0.00461
# => Validation Accuracy did not improve
# epoch [837/1001], MSE_loss:0.00112
# => Validation Accuracy did not improve
# epoch [838/1001], MSE_loss:0.00086
# => Validation Accuracy did not improve
# epoch [839/1001], MSE_loss:0.00091
# => Validation Accuracy did not improve
# epoch [840/1001], MSE_loss:0.00102
# => Validation Accuracy did not improve
# epoch [841/1001], MSE_loss:0.00375
# => Validation Accuracy did not improve
# epoch [842/1001], MSE_loss:0.00056
# => Validation Accuracy did not improve
# epoch [843/1001], MSE_loss:0.00531
# => Validation Accuracy did not improve
# epoch [844/1001], MSE_loss:0.00369
# => Validation Accuracy did not improve
# epoch [845/1001], MSE_loss:0.00136
# => Validation Accuracy did not improve
# epoch [846/1001], MSE_loss:0.00150
# => Validation Accuracy did not improve
# epoch [847/1001], MSE_loss:0.00227
# => Validation Accuracy did not improve
# epoch [848/1001], MSE_loss:0.00119
# => Validation Accuracy did not improve
# epoch [849/1001], MSE_loss:0.00048
# => Validation Accuracy did not improve
# epoch [850/1001], MSE_loss:0.00085
# => Validation Accuracy did not improve
# epoch [851/1001], MSE_loss:0.00206
# => Validation Accuracy did not improve
# epoch [852/1001], MSE_loss:0.01257
# => Validation Accuracy did not improve
# epoch [853/1001], MSE_loss:0.00447
# => Validation Accuracy did not improve
# epoch [854/1001], MSE_loss:0.00328
# => Validation Accuracy did not improve
# epoch [855/1001], MSE_loss:0.00264
# => Validation Accuracy did not improve
# epoch [856/1001], MSE_loss:0.00032
# => Validation Accuracy did not improve
# epoch [857/1001], MSE_loss:0.00146
# => Validation Accuracy did not improve
# epoch [858/1001], MSE_loss:0.00937
# => Validation Accuracy did not improve
# epoch [859/1001], MSE_loss:0.00025
# => Validation Accuracy did not improve
# epoch [860/1001], MSE_loss:0.00142
# => Validation Accuracy did not improve
# epoch [861/1001], MSE_loss:0.00088
# => Validation Accuracy did not improve
# epoch [862/1001], MSE_loss:0.00223
# => Validation Accuracy did not improve
# epoch [863/1001], MSE_loss:0.00065
# => Validation Accuracy did not improve
# epoch [864/1001], MSE_loss:0.00329
# => Validation Accuracy did not improve
# epoch [865/1001], MSE_loss:0.00080
# => Validation Accuracy did not improve
# epoch [866/1001], MSE_loss:0.00397
# => Validation Accuracy did not improve
# epoch [867/1001], MSE_loss:0.00244
# => Validation Accuracy did not improve
# epoch [868/1001], MSE_loss:0.00107
# => Validation Accuracy did not improve
# epoch [869/1001], MSE_loss:0.00080
# => Validation Accuracy did not improve
# epoch [870/1001], MSE_loss:0.00162
# => Validation Accuracy did not improve
# epoch [871/1001], MSE_loss:0.00124
# => Validation Accuracy did not improve
# epoch [872/1001], MSE_loss:0.00069
# => Validation Accuracy did not improve
# epoch [873/1001], MSE_loss:0.00208
# => Validation Accuracy did not improve
# epoch [874/1001], MSE_loss:0.00081
# => Validation Accuracy did not improve
# epoch [875/1001], MSE_loss:0.00541
# => Validation Accuracy did not improve
# epoch [876/1001], MSE_loss:0.00077
# => Validation Accuracy did not improve
# epoch [877/1001], MSE_loss:0.00216
# => Validation Accuracy did not improve
# epoch [878/1001], MSE_loss:0.00080
# => Validation Accuracy did not improve
# epoch [879/1001], MSE_loss:0.00032
# => Validation Accuracy did not improve
# epoch [880/1001], MSE_loss:0.00022
# => Validation Accuracy did not improve
# epoch [881/1001], MSE_loss:0.00931
# => Validation Accuracy did not improve
# epoch [882/1001], MSE_loss:0.00074
# => Validation Accuracy did not improve
# epoch [883/1001], MSE_loss:0.00061
# => Validation Accuracy did not improve
# epoch [884/1001], MSE_loss:0.00444
# => Validation Accuracy did not improve
# epoch [885/1001], MSE_loss:0.00208
# => Validation Accuracy did not improve
# epoch [886/1001], MSE_loss:0.00392
# => Validation Accuracy did not improve
# epoch [887/1001], MSE_loss:0.00260
# => Validation Accuracy did not improve
# epoch [888/1001], MSE_loss:0.00394
# => Validation Accuracy did not improve
# epoch [889/1001], MSE_loss:0.00118
# => Validation Accuracy did not improve
# epoch [890/1001], MSE_loss:0.00069
# => Validation Accuracy did not improve
# epoch [891/1001], MSE_loss:0.00048
# => Validation Accuracy did not improve
# epoch [892/1001], MSE_loss:0.00025
# => Validation Accuracy did not improve
# epoch [893/1001], MSE_loss:0.00250
# => Validation Accuracy did not improve
# epoch [894/1001], MSE_loss:0.00378
# => Validation Accuracy did not improve
# epoch [895/1001], MSE_loss:0.00015
# => Validation Accuracy did not improve
# epoch [896/1001], MSE_loss:0.00094
# => Validation Accuracy did not improve
# epoch [897/1001], MSE_loss:0.00073
# => Validation Accuracy did not improve
# epoch [898/1001], MSE_loss:0.00561
# => Validation Accuracy did not improve
# epoch [899/1001], MSE_loss:0.00415
# => Validation Accuracy did not improve
# epoch [900/1001], MSE_loss:0.00096
# => Validation Accuracy did not improve
# epoch [901/1001], MSE_loss:0.00275
# => Validation Accuracy did not improve
# epoch [902/1001], MSE_loss:0.00178
# => Validation Accuracy did not improve
# epoch [903/1001], MSE_loss:0.00166
# => Validation Accuracy did not improve
# epoch [904/1001], MSE_loss:0.00669
# => Validation Accuracy did not improve
# epoch [905/1001], MSE_loss:0.00347
# => Validation Accuracy did not improve
# epoch [906/1001], MSE_loss:0.00486
# => Validation Accuracy did not improve
# epoch [907/1001], MSE_loss:0.00142
# => Validation Accuracy did not improve
# epoch [908/1001], MSE_loss:0.00516
# => Validation Accuracy did not improve
# epoch [909/1001], MSE_loss:0.00060
# => Validation Accuracy did not improve
# epoch [910/1001], MSE_loss:0.00284
# => Validation Accuracy did not improve
# epoch [911/1001], MSE_loss:0.00381
# => Validation Accuracy did not improve
# epoch [912/1001], MSE_loss:0.00200
# => Validation Accuracy did not improve
# epoch [913/1001], MSE_loss:0.00338
# => Validation Accuracy did not improve
# epoch [914/1001], MSE_loss:0.00334
# => Validation Accuracy did not improve
# epoch [915/1001], MSE_loss:0.00669
# => Validation Accuracy did not improve
# epoch [916/1001], MSE_loss:0.00027
# => Validation Accuracy did not improve
# epoch [917/1001], MSE_loss:0.00072
# => Validation Accuracy did not improve
# epoch [918/1001], MSE_loss:0.00986
# => Validation Accuracy did not improve
# epoch [919/1001], MSE_loss:0.00246
# => Validation Accuracy did not improve
# epoch [920/1001], MSE_loss:0.00476
# => Validation Accuracy did not improve
# epoch [921/1001], MSE_loss:0.00091
# => Validation Accuracy did not improve
# epoch [922/1001], MSE_loss:0.00465
# => Validation Accuracy did not improve
# epoch [923/1001], MSE_loss:0.00394
# => Validation Accuracy did not improve
# epoch [924/1001], MSE_loss:0.00206
# => Validation Accuracy did not improve
# epoch [925/1001], MSE_loss:0.00106
# => Validation Accuracy did not improve
# epoch [926/1001], MSE_loss:0.00152
# => Validation Accuracy did not improve
# epoch [927/1001], MSE_loss:0.00127
# => Validation Accuracy did not improve
# epoch [928/1001], MSE_loss:0.00104
# => Validation Accuracy did not improve
# epoch [929/1001], MSE_loss:0.00242
# => Validation Accuracy did not improve
# epoch [930/1001], MSE_loss:0.00202
# => Validation Accuracy did not improve
# epoch [931/1001], MSE_loss:0.00094
# => Validation Accuracy did not improve
# epoch [932/1001], MSE_loss:0.00561
# => Validation Accuracy did not improve
# epoch [933/1001], MSE_loss:0.00127
# => Validation Accuracy did not improve
# epoch [934/1001], MSE_loss:0.00487
# => Validation Accuracy did not improve
# epoch [935/1001], MSE_loss:0.00015
# => Validation Accuracy did not improve
# epoch [936/1001], MSE_loss:0.00444
# => Validation Accuracy did not improve
# epoch [937/1001], MSE_loss:0.00398
# => Validation Accuracy did not improve
# epoch [938/1001], MSE_loss:0.01148
# => Validation Accuracy did not improve
# epoch [939/1001], MSE_loss:0.00027
# => Validation Accuracy did not improve
# epoch [940/1001], MSE_loss:0.00112
# => Validation Accuracy did not improve
# epoch [941/1001], MSE_loss:0.01096
# => Validation Accuracy did not improve
# epoch [942/1001], MSE_loss:0.00292
# => Validation Accuracy did not improve
# epoch [943/1001], MSE_loss:0.00208
# => Validation Accuracy did not improve
# epoch [944/1001], MSE_loss:0.00985
# => Validation Accuracy did not improve
# epoch [945/1001], MSE_loss:0.00284
# => Validation Accuracy did not improve
# epoch [946/1001], MSE_loss:0.00219
# => Validation Accuracy did not improve
# epoch [947/1001], MSE_loss:0.00091
# => Validation Accuracy did not improve
# epoch [948/1001], MSE_loss:0.00139
# => Validation Accuracy did not improve
# epoch [949/1001], MSE_loss:0.00027
# => Validation Accuracy did not improve
# epoch [950/1001], MSE_loss:0.00346
# => Validation Accuracy did not improve
# epoch [951/1001], MSE_loss:0.00060
# => Validation Accuracy did not improve
# epoch [952/1001], MSE_loss:0.00206
# => Validation Accuracy did not improve
# epoch [953/1001], MSE_loss:0.00458
# => Validation Accuracy did not improve
# epoch [954/1001], MSE_loss:0.00454
# => Validation Accuracy did not improve
# epoch [955/1001], MSE_loss:0.00196
# => Validation Accuracy did not improve
# epoch [956/1001], MSE_loss:0.00155
# => Validation Accuracy did not improve
# epoch [957/1001], MSE_loss:0.00394
# => Validation Accuracy did not improve
# epoch [958/1001], MSE_loss:0.00048
# => Validation Accuracy did not improve
# epoch [959/1001], MSE_loss:0.00071
# => Validation Accuracy did not improve
# epoch [960/1001], MSE_loss:0.00323
# => Validation Accuracy did not improve
# epoch [961/1001], MSE_loss:0.00047
# => Validation Accuracy did not improve
# epoch [962/1001], MSE_loss:0.00260
# => Validation Accuracy did not improve
# epoch [963/1001], MSE_loss:0.00102
# => Validation Accuracy did not improve
# epoch [964/1001], MSE_loss:0.00444
# => Validation Accuracy did not improve
# epoch [965/1001], MSE_loss:0.00034
# => Validation Accuracy did not improve
# epoch [966/1001], MSE_loss:0.00047
# => Validation Accuracy did not improve
# epoch [967/1001], MSE_loss:0.00169
# => Validation Accuracy did not improve
# epoch [968/1001], MSE_loss:0.00232
# => Validation Accuracy did not improve
# epoch [969/1001], MSE_loss:0.00486
# => Validation Accuracy did not improve
# epoch [970/1001], MSE_loss:0.00142
# => Validation Accuracy did not improve
# epoch [971/1001], MSE_loss:0.00250
# => Validation Accuracy did not improve
# epoch [972/1001], MSE_loss:0.00071
# => Validation Accuracy did not improve
# epoch [973/1001], MSE_loss:0.00372
# => Validation Accuracy did not improve
# epoch [974/1001], MSE_loss:0.00075
# => Validation Accuracy did not improve
# epoch [975/1001], MSE_loss:0.00324
# => Validation Accuracy did not improve
# epoch [976/1001], MSE_loss:0.00030
# => Validation Accuracy did not improve
# epoch [977/1001], MSE_loss:0.00074
# => Validation Accuracy did not improve
# epoch [978/1001], MSE_loss:0.00048
# => Validation Accuracy did not improve
# epoch [979/1001], MSE_loss:0.00223
# => Validation Accuracy did not improve
# epoch [980/1001], MSE_loss:0.00367
# => Validation Accuracy did not improve
# epoch [981/1001], MSE_loss:0.00394
# => Validation Accuracy did not improve
# epoch [982/1001], MSE_loss:0.00263
# => Validation Accuracy did not improve
# epoch [983/1001], MSE_loss:0.00020
# => Validation Accuracy did not improve
# epoch [984/1001], MSE_loss:0.00852
# => Validation Accuracy did not improve
# epoch [985/1001], MSE_loss:0.00398
# => Validation Accuracy did not improve
# epoch [986/1001], MSE_loss:0.00046
# => Validation Accuracy did not improve
# epoch [987/1001], MSE_loss:0.00281
# => Validation Accuracy did not improve
# epoch [988/1001], MSE_loss:0.00054
# => Validation Accuracy did not improve
# epoch [989/1001], MSE_loss:0.00178
# => Validation Accuracy did not improve
# epoch [990/1001], MSE_loss:0.00194
# => Validation Accuracy did not improve
# epoch [991/1001], MSE_loss:0.00065
# => Validation Accuracy did not improve
# epoch [992/1001], MSE_loss:0.00594
# => Validation Accuracy did not improve
# epoch [993/1001], MSE_loss:0.00138
# => Validation Accuracy did not improve
# epoch [994/1001], MSE_loss:0.00085
# => Validation Accuracy did not improve
# epoch [995/1001], MSE_loss:0.00386
# => Validation Accuracy did not improve
# epoch [996/1001], MSE_loss:0.00070
# => Validation Accuracy did not improve
# epoch [997/1001], MSE_loss:0.00211
# => Validation Accuracy did not improve
# epoch [998/1001], MSE_loss:0.00275
# => Validation Accuracy did not improve
# epoch [999/1001], MSE_loss:0.00119
# => Validation Accuracy did not improve
# epoch [1000/1001], MSE_loss:0.00085
# => Validation Accuracy did not improve
# epoch [1001/1001], MSE_loss:0.00411
# => Validation Accuracy did not improve

# %% [markdown]
# # Get latent features

# %%
input_data = cov_data.to(device)

latent_features = autoencoder.encode(input_data).detach().cpu().numpy()

print(latent_features.shape)
# Out:
# (801, 3)

# %% [markdown]
# # K-Means clustering

# %%
num_clusters = [3,5,7]

pred_labels = np.empty( (len(num_clusters), latent_features.shape[0]) )
pred_center = []

for i, n_c in enumerate(num_clusters):
    cluster = KMeans(n_clusters=n_c, random_state=0, n_init=10*n_c).fit(latent_features)

    centroid = cluster.cluster_centers_ # [n_clusters, n_chs]
    pred_center.append(centroid)
    pred_labels[i] = cluster.labels_

pred_labels += 1

# %%
# with open('./auto_encoder_saves/auto_encoder_clustering_results.pkl', 'wb') as f:
#     dill.dump([Cov_mat, cov_data, pred_center, pred_labels, centroid], f)

# %%
with open('./auto_encoder_saves/auto_encoder_clustering_results.pkl', 'rb') as f:
    [Cov_mat, cov_data, pred_center, pred_labels, centroid] = dill.load(f)

# %% [markdown]
# # T-SNE visualization

# %%
colors = sns.color_palette('pastel')

for ind, n_c in enumerate(num_clusters): 

    tsne = TSNE(n_components=2, init='pca', random_state=0, n_jobs=-1, perplexity=30)

    lf_with_center = np.vstack((latent_features, pred_center[ind]))

    kmeans_2d_with_center = tsne.fit_transform(lf_with_center)    
    kmeans_2d = kmeans_2d_with_center[:-n_c, :]
    kmeans_2d_center = kmeans_2d_with_center[-n_c:, :]

    fig, axi1=plt.subplots(1, figsize=(2, 1.5))    
    for i in range(n_c):
        axi1.scatter(kmeans_2d[pred_labels[ind] == i+1, 0], 
                     kmeans_2d[pred_labels[ind] == i+1, 1],
                     marker='*',
                     s=10,
                     color=colors[i],
                    )
        axi1.text(kmeans_2d_center[i,0], kmeans_2d_center[i,1], 
                  i+1, fontsize=10, fontweight='semibold', 
                  verticalalignment='center', horizontalalignment='center', 
                  color='black', 
                )

    ax = plt.gca()
    plt.xlim([-50, 50])
    plt.ylim([-50, 50])
    plt.grid(True, linewidth=0.5, color='gray', linestyle=':')

    plt.yticks([-50,-25,0,25,50],[-50,-25,0,25,50])
    plt.xticks([-50,-25,0,25,50],[-50,-25,0,25,50])

    ax.tick_params(which='both', bottom=True, top=False, left=True, right=False,
                labelbottom=True, labelleft=True, direction='out',width=1)
    plt.show()

# %% [markdown]
# # Plot microstate series

# %%
for n_c in range(len(num_clusters)):
    draw_states.draw_state_blocks_for_generated_data(pred_labels[n_c], figsize=(3.5, 1.0), 
                                                     n_clusters=int(np.max(pred_labels[n_c])),
                                                     colorbar_fraction=0.015, tmin=0.1, tmax=0.9, 
                                                     colorbar_ticks=[]);

# %% [markdown]
# # t-test of clustering results

# %% [markdown]
# ## Calculate spatial distance between two covariance matrices

# %%
tp = Cov_mat.shape[0]

cov_dist_uptri = np.full((tp, tp), np.nan)
cov_dist = np.ones((tp, tp))

for i in range(tp):
    for j in range(i+1, tp):        
        cov1 = Cov_mat[i]
        cov2 = Cov_mat[j]

        evals,_ = scipy.linalg.eigh(cov1,cov2)
        dist = np.log(evals[-1])

        cov_dist_uptri[i,j] = dist
        cov_dist[i,j] = dist
        cov_dist[j,i] = dist

# %%
fig, ax = plt.subplots(figsize=(1.7, 1.7))
ax0 = ax.matshow(cov_dist_uptri, interpolation='none', vmin=0.0, vmax=5.0, cmap='jet'); 
clb = fig.colorbar(ax0, fraction=0.045);
ax.xaxis.set_ticks_position("bottom")
plt.grid(color='gray', linestyle=':', linewidth=0.5);
clb.set_ticks(ticks=[0, 2.5, 5])
cbar_label = clb.ax.get_xticklabels() + clb.ax.get_yticklabels()
[lab.set_font('Arial') for lab in cbar_label]  #Times New Roman  #set_fontstyle
clb.ax.tick_params(labelsize=10)
ax.set_xticks(np.arange(0,801,200), np.arange(0,801,200), fontdict=font);
ax.set_yticks(np.arange(0,801,200), np.arange(0,801,200), fontdict=font);
plt.show();

# %%
for n_c in range(len(num_clusters)):
    p_res = ttest_for_clusters.distance_ttest(pred_labels[n_c], cov_dist, samp_num=500)
    # ttest_for_clusters.draw_test_mat(p_res, corr_p=False)
    ttest_for_clusters.draw_test_mat(p_res, corr_p=True)
# Out:
# []
# []
# []

# %% [markdown]
# # Calculate errors

# %%
for i in range(3):
    # SSE, Distance, CH_Score, SI_Score, DB_Score
    values = calc_diff(crop_eeg.T, pred_labels[i])
    print(values)
# Out:
# (139.08384802323206, 11.793381534709715, 0.41931155132781045, -0.03266057847406908, 73.92797286038395)
# (138.21328469012275, 11.756414618842037, 1.4638878870929475, -0.10081344380227678, 30.786863293060918)
# (135.38948553060823, 11.635698755580098, 3.753834205403106, -0.16508308269028743, 34.82538167195545)
